# %% [markdown]
# # Iris plot

# %%
#| label: fig-iris-plot-mpl
#| fig-cap: >
#|   The iris data

import plotly.express as px
import matplotlib.pyplot as plt
df = px.data.iris()
plt.scatter(df['sepal_width'], df['sepal_length'])
